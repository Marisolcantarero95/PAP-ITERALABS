# %%
# Importando Paquetes
import requests
import pandas as pd
import plotly.plotly as py
import cufflinks as cf
import numpy as np
from sklearn.neighbors.kde import KernelDensity
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot
import scipy.stats as st
import statsmodels.datasets
import plotly.plotly as py
from plotly import tools
from datetime import datetime
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
from scipy.stats import norm
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
import numpy as np
from scipy import stats as st
# %matplotlib inline
import warnings
pd.set_option('precision',2)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
data=pd.read_json(r'C:\Users\luism\OneDrive\Escritorio\data\VALUACION_20190705_174227_TRAYECTORIA_0.json')
data1=pd.read_json(r'C:\Users\luism\OneDrive\Escritorio\data\VALUACION_20190705_174227_TRAYECTORIA_1.json')
data2=pd.read_json(r'C:\Users\luism\OneDrive\Escritorio\data\VALUACION_20190705_174227_TRAYECTORIA_2.json')
data3=pd.read_json(r'C:\Users\luism\OneDrive\Escritorio\data\VALUACION_20190705_174227_TRAYECTORIA_3.json')
data4=pd.read_json(r'C:\Users\luism\OneDrive\Escritorio\data\VALUACION_20190705_174227_TRAYECTORIA_4.json')

# %%
var=data['resultado_0']['datos']['flujos']['ingresos_totales']
varz= { i : var[i] for i in range(0, len(var) ) }
var1= data1['resultado_1']['datos']['flujos']['ingresos_totales']
varz1= { i : var1[i] for i in range(0, len(var1) ) }
var2= data2['resultado_2']['datos']['flujos']['ingresos_totales']
varz2= { i : var1[i] for i in range(0, len(var2) ) }
var3= data3['resultado_3']['datos']['flujos']['ingresos_totales']
varz3= { i : var1[i] for i in range(0, len(var3) ) }
var4=data4['resultado_4']['datos']['flujos']['ingresos_totales']
varz4= { i : var1[i] for i in range(0, len(var4) ) }

# %%
df = pd.DataFrame([[key, varz[key]] for key in varz.keys()], columns=['indice','ingresos_totales_0'])
df1=pd.DataFrame([[key, varz1[key]] for key in varz1.keys()], columns=['indice','ingresos_totales_1'])
df2=pd.DataFrame([[key, varz2[key]] for key in varz2.keys()], columns=['indice','ingresos_totales_2'])
df3=pd.DataFrame([[key, varz3[key]] for key in varz3.keys()], columns=['indice','ingresos_totales_3'])
df4=pd.DataFrame([[key, varz4[key]] for key in varz4.keys()], columns=['indice','ingresos_totales_4'])

# %%
serie_0 = go.Scatter(
                x=df['indice'],
                y=df['ingresos_totales_0'],
                name = "Serie limite superior",
                line = dict(color = '#17BECF'),
                opacity = 0.8)

serie_1 = go.Scatter(
                x=df1['indice'],
                y=df1['ingresos_totales_1'],
                name = "Serie_tiempo iteracion 2",
                line = dict(color = '#7F7F7F'),
                opacity = 0.8)
serie_2 = go.Scatter(
                x=df2['indice'],
                y=df2['ingresos_totales_2'],
                name = "Serie_tiempo iteracion 3",
                line = dict(color = '#7F7F7F'),
                opacity = 0.8)
serie_3 = go.Scatter(
                x=df3['indice'],
                y=df3['ingresos_totales_3'],
                name = "Serie_tiempo iteracion 3",
                line = dict(color = '#7F7F7F'),
                opacity = 0.8)
serie_4 = go.Scatter(
                x=df4['indice'],
                y=df4['ingresos_totales_4'],
                name = "Serie milite inferior",
                line = dict(color = '#7F7F7F'),
                opacity = 0.8)

data = [serie_0,serie_1,serie_2,serie_3,serie_4]

layout = dict(
    title = "Manually Set Date Range",
    xaxis = dict(
        range = [0,96])
)

fig = dict(data=data, layout=layout)
iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="a6bc3cdf-f1e9-4237-896d-279c19069cd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a6bc3cdf-f1e9-4237-896d-279c19069cd3")) {
#                     Plotly.newPlot(
#                         'a6bc3cdf-f1e9-4237-896d-279c19069cd3',
# ...
